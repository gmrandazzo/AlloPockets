# %% [markdown]
# STINGAllo ran in website: https://www.stingallo.cbi.cnptia.embrapa.br/sting

# %%
import pandas as pd
from pathlib import Path

# %%
news = sorted(pd.read_pickle("../../../training_data/8.Apos/Extra_set/pockets_features.pkl").keys())

news
# Out:
# ['2gk9',
#  '2gs3',
#  '2ojx',
#  '3pfv',
#  '4n22',
#  '5c97',
#  '5e1i',
#  '5e97',
#  '5uak',
#  '6gx3',
#  '6uen',
#  '6yhr',
#  '6z1h',
#  '7l6r',
#  '7v37',
#  '7xlq',
#  '8sgj',
#  '8szq',
#  '8y6y',
#  '8yf0',
#  '9di2',
#  '9di9',
#  '9fsk',
#  '9ouk']

# %%
p = Path(".")#.resolve()
for pdb in news:
    if len(tuple(p.glob(f"{pdb}*"))) == 0:
        print(pdb)

# %%
for pdb in news:
    for f in p.glob(f"{pdb}*"):
        if "_fail" not in f.name:
            print(pdb)
# Out:
# 2gk9
# 2gs3
# 3pfv
# 5e97
# 6gx3
# 6yhr
# 9di2
# 9di9

# %%
for pdb in news:
    for f in p.glob(f"{pdb}*"):
        with open(f, "r") as fh:
            try:
                if "AFR results for:" in fh.read():
                    print(pdb)
            except:
                print(f)
                raise
# Out:
# 2gk9
# 2gs3
# 3pfv
# 5e97
# 6gx3
# 6yhr
# 9di2
# 9di9

# %%
for pdb in news:
    for f in p.glob(f"{pdb}*"):
        with open(f, "r") as fh:
            ls = fh.readlines()
            for i, l in enumerate(ls):
                if "AFR results" in l and "chain" in l:
                    print(pdb, "".join(ls[i:]), "\n")
                    break
# Out:
# 2gk9 AFR results for: 2gk9 (1).pdb, chain A
# residue_name residue_number
# MET 203
# Process completed.
#
# 2gs3 AFR results for: 2gs3.pdb, chain A
# residue_name residue_number
# TYR 59
# Process completed.
#
# 3pfv AFR results for: 3pfv.pdb, chain A
# residue_name residue_number
# ASP 221
# LEU 239
# SER 218
# Process completed.
#
# 5e97 AFR results for: 5e97.pdb, chain A
# residue_name residue_number
# LEU 393
# LEU 408
# Process completed.
#
# 6gx3 AFR results for: 6gx3 (1).pdb, chain D
# residue_name residue_number
# VAL 208
# Process completed.
#
# 6yhr AFR results for: 6yhr.pdb, chain A
# residue_name residue_number
# GLY 960
# Process completed.
#
# 9di2 AFR results for: 9di2 (1).pdb, chain B
# residue_name residue_number
# GLY 422
# Process completed.
#
# 9di9 AFR results for: 9di9 (1).pdb, chain A
# residue_name residue_number
# GLY 339
# Process completed.

# %%
import pickle
import pandas as pd

# %%
resultsf = "stingallo_results.pkl"

results = {
    "2gk9": {
        "pocket": {
            "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["203",]})
        }
    },
    "2gs3": {
        "pocket": {
            "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["59",]})
        }
    },
    "3pfv": {
        "pocket1": {
            "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["221",]})
        },
        "pocket2": {
            "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["239",]})
        },
        "pocket3": {
            "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["218",]})
        },
    },
    "5e97": {
        "pocket1": {
            "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["393",]})
        },
        "pocket2": {
            "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["408",]})
        },
    },
    "6gx3": {
        "pocket": {
            "residues": pd.DataFrame({"auth_asym_id": ["D",], "auth_seq_id": ["208",]})
        }
    },
    "6yhr": {
        "pocket": {
            "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["960",]})
        }
    },
    "9di2": {
        "pocket": {
            "residues": pd.DataFrame({"auth_asym_id": ["B",], "auth_seq_id": ["422",]})
        }
    },
    "9di9": {
        "pocket": {
            "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["339",]})
        }
    },
    # "7sns": {
    #     "pocket1": {
    #         "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["96",]})
    #     },
    #     "pocket2": {
    #         "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["107",]})
    #     },
    #     "pocket3": {
    #         "residues": pd.DataFrame({"auth_asym_id": ["A",], "auth_seq_id": ["111",]})
    #     },
    # },
}

with open(resultsf, "wb") as f:
    results = pickle.dump(results, f)
